# %% [markdown]
# # Data driven building simulation
#
# In this learning-machine code, we are using data taken from paper: "On-line learning of indoor temperature forecasting models towards energy efficiency".
# This dataset is collected from a monitor system settled in a domotic house near Valencia, built by Cardinal Herrera University. It corresponds to approximately 40 days of monitoring data, which are sampled every 15 minutes.
# The first aim of the project is to investigate the correlation between outside and inside parameters. Then we proceed with the building of a model in order to predict the indoor temperature variation as a function of all the other data which are related to it.

# %%
#importing dataset 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DataFolderPath = "C:\Users\Utente\Dropbox\Building systems group project\DataDrivenAnalysis\Temperature Prediction in a Domotic House--Bortolotti-Martinelli-Spirito"
FileName= "NEW-DATA-1.T15.txt"
FilePath = DataFolderPath+"\\"+FileName

# combining first and second columns to create a unique index column (date+time)
DataFrame = pd.read_csv(FilePath, sep= " ", index_col=6)
DataFrame["period"] = DataFrame["1:Date"].map(str) + " " + DataFrame["2:Time"].map(str)
DataFrame.index = DataFrame["period"]

# %%
# convert indexes from dtype 'object' to 'datetime'
previousIndex = DataFrame.index 
ParsedIndex = pd.to_datetime(previousIndex)
DataFrame.index = ParsedIndex

# %%
# selecting a specific time interval and removing the NaNs
DF_myChosenDates = DataFrame["2012-03-20 12:00:00 ":"2012-03-26 12:00:00 "]
DF_cleaned = DF_myChosenDates.dropna()

# %%
# looking for a correlation among data 
DF_cleaned.corr()
# Out:
#                                  3:Temperature_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                         1.000000
# 4:Temperature_Habitacion_Sensor                      0.996328
# 5:Weather_Temperature                                0.718754
# 6:CO2_Comedor_Sensor                                 0.211957
# 8:Humedad_Comedor_Sensor                             0.326259
# 9:Humedad_Habitacion_Sensor                         -0.303475
# 10:Lighting_Comedor_Sensor                           0.114046
# 11:Lighting_Habitacion_Sensor                        0.047313
# 12:Precipitacion                                    -0.381150
# 13:Meteo_Exterior_Crepusculo                         0.074400
# 14:Meteo_Exterior_Viento                            -0.140582
# 15:Meteo_Exterior_Sol_Oest                           0.358659
# 16:Meteo_Exterior_Sol_Est                           -0.200833
# 17:Meteo_Exterior_Sol_Sud                            0.063966
# 18:Meteo_Exterior_Piranometro                        0.156465
# 19:Exterior_Entalpic_1                                    NaN
# 20:Exterior_Entalpic_2                                    NaN
# 21:Exterior_Entalpic_turbo                                NaN
# 22:Temperature_Exterior_Sensor                       0.863681
# 23:Humedad_Exterior_Sensor                          -0.701744
# 24:Day_Of_Week                                       0.487941
#
#                                  4:Temperature_Habitacion_Sensor  \
# 3:Temperature_Comedor_Sensor                            0.996328
# 4:Temperature_Habitacion_Sensor                         1.000000
# 5:Weather_Temperature                                   0.749030
# 6:CO2_Comedor_Sensor                                    0.219386
# 8:Humedad_Comedor_Sensor                                0.312151
# 9:Humedad_Habitacion_Sensor                            -0.299849
# 10:Lighting_Comedor_Sensor                              0.162781
# 11:Lighting_Habitacion_Sensor                           0.088147
# 12:Precipitacion                                       -0.367306
# 13:Meteo_Exterior_Crepusculo                            0.100660
# 14:Meteo_Exterior_Viento                               -0.099922
# 15:Meteo_Exterior_Sol_Oest                              0.385210
# 16:Meteo_Exterior_Sol_Est                              -0.207803
# 17:Meteo_Exterior_Sol_Sud                               0.103537
# 18:Meteo_Exterior_Piranometro                           0.201015
# 19:Exterior_Entalpic_1                                       NaN
# 20:Exterior_Entalpic_2                                       NaN
# 21:Exterior_Entalpic_turbo                                   NaN
# 22:Temperature_Exterior_Sensor                          0.886487
# 23:Humedad_Exterior_Sensor                             -0.691107
# 24:Day_Of_Week                                          0.475587
#
#                                  5:Weather_Temperature  6:CO2_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                  0.718754              0.211957
# 4:Temperature_Habitacion_Sensor               0.749030              0.219386
# 5:Weather_Temperature                         1.000000              0.252822
# 6:CO2_Comedor_Sensor                          0.252822              1.000000
# 8:Humedad_Comedor_Sensor                      0.073196              0.035547
# 9:Humedad_Habitacion_Sensor                  -0.295314             -0.148501
# 10:Lighting_Comedor_Sensor                    0.585585              0.317530
# 11:Lighting_Habitacion_Sensor                 0.524364              0.305842
# 12:Precipitacion                             -0.181613             -0.156385
# 13:Meteo_Exterior_Crepusculo                  0.445997              0.145326
# 14:Meteo_Exterior_Viento                      0.309309              0.051682
# 15:Meteo_Exterior_Sol_Oest                    0.547104              0.117886
# 16:Meteo_Exterior_Sol_Est                     0.017039              0.027292
# 17:Meteo_Exterior_Sol_Sud                     0.521690              0.296029
# 18:Meteo_Exterior_Piranometro                 0.617818              0.306637
# 19:Exterior_Entalpic_1                             NaN                   NaN
# 20:Exterior_Entalpic_2                             NaN                   NaN
# 21:Exterior_Entalpic_turbo                         NaN                   NaN
# 22:Temperature_Exterior_Sensor                0.944728              0.259769
# 23:Humedad_Exterior_Sensor                   -0.559645             -0.240730
# 24:Day_Of_Week                                0.292084             -0.150782
#
#                                  8:Humedad_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                     0.326259
# 4:Temperature_Habitacion_Sensor                  0.312151
# 5:Weather_Temperature                            0.073196
# 6:CO2_Comedor_Sensor                             0.035547
# 8:Humedad_Comedor_Sensor                         1.000000
# 9:Humedad_Habitacion_Sensor                      0.589413
# 10:Lighting_Comedor_Sensor                      -0.096728
# 11:Lighting_Habitacion_Sensor                   -0.079661
# 12:Precipitacion                                -0.726122
# 13:Meteo_Exterior_Crepusculo                    -0.174787
# 14:Meteo_Exterior_Viento                        -0.615794
# 15:Meteo_Exterior_Sol_Oest                      -0.037898
# 16:Meteo_Exterior_Sol_Est                        0.009443
# 17:Meteo_Exterior_Sol_Sud                       -0.062619
# 18:Meteo_Exterior_Piranometro                   -0.077746
# 19:Exterior_Entalpic_1                                NaN
# 20:Exterior_Entalpic_2                                NaN
# 21:Exterior_Entalpic_turbo                            NaN
# 22:Temperature_Exterior_Sensor                   0.220221
# 23:Humedad_Exterior_Sensor                      -0.180180
# 24:Day_Of_Week                                   0.359899
#
#                                  9:Humedad_Habitacion_Sensor  \
# 3:Temperature_Comedor_Sensor                       -0.303475
# 4:Temperature_Habitacion_Sensor                    -0.299849
# 5:Weather_Temperature                              -0.295314
# 6:CO2_Comedor_Sensor                               -0.148501
# 8:Humedad_Comedor_Sensor                            0.589413
# 9:Humedad_Habitacion_Sensor                         1.000000
# 10:Lighting_Comedor_Sensor                         -0.269673
# 11:Lighting_Habitacion_Sensor                      -0.278584
# 12:Precipitacion                                   -0.295098
# 13:Meteo_Exterior_Crepusculo                       -0.314129
# 14:Meteo_Exterior_Viento                           -0.270281
# 15:Meteo_Exterior_Sol_Oest                         -0.166022
# 16:Meteo_Exterior_Sol_Est                          -0.178558
# 17:Meteo_Exterior_Sol_Sud                          -0.280088
# 18:Meteo_Exterior_Piranometro                      -0.282370
# 19:Exterior_Entalpic_1                                   NaN
# 20:Exterior_Entalpic_2                                   NaN
# 21:Exterior_Entalpic_turbo                               NaN
# 22:Temperature_Exterior_Sensor                     -0.257254
# 23:Humedad_Exterior_Sensor                          0.564098
# 24:Day_Of_Week                                     -0.005104
#
#                                  10:Lighting_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                       0.114046
# 4:Temperature_Habitacion_Sensor                    0.162781
# 5:Weather_Temperature                              0.585585
# 6:CO2_Comedor_Sensor                               0.317530
# 8:Humedad_Comedor_Sensor                          -0.096728
# 9:Humedad_Habitacion_Sensor                       -0.269673
# 10:Lighting_Comedor_Sensor                         1.000000
# 11:Lighting_Habitacion_Sensor                      0.957156
# 12:Precipitacion                                  -0.158452
# 13:Meteo_Exterior_Crepusculo                       0.637385
# 14:Meteo_Exterior_Viento                           0.351497
# 15:Meteo_Exterior_Sol_Oest                         0.428251
# 16:Meteo_Exterior_Sol_Est                          0.403537
# 17:Meteo_Exterior_Sol_Sud                          0.949803
# 18:Meteo_Exterior_Piranometro                      0.960062
# 19:Exterior_Entalpic_1                                  NaN
# 20:Exterior_Entalpic_2                                  NaN
# 21:Exterior_Entalpic_turbo                              NaN
# 22:Temperature_Exterior_Sensor                     0.463075
# 23:Humedad_Exterior_Sensor                        -0.331583
# 24:Day_Of_Week                                     0.051751
#
#                                  11:Lighting_Habitacion_Sensor  \
# 3:Temperature_Comedor_Sensor                          0.047313
# 4:Temperature_Habitacion_Sensor                       0.088147
# 5:Weather_Temperature                                 0.524364
# 6:CO2_Comedor_Sensor                                  0.305842
# 8:Humedad_Comedor_Sensor                             -0.079661
# 9:Humedad_Habitacion_Sensor                          -0.278584
# 10:Lighting_Comedor_Sensor                            0.957156
# 11:Lighting_Habitacion_Sensor                         1.000000
# 12:Precipitacion                                     -0.167413
# 13:Meteo_Exterior_Crepusculo                          0.623931
# 14:Meteo_Exterior_Viento                              0.270169
# 15:Meteo_Exterior_Sol_Oest                            0.316715
# 16:Meteo_Exterior_Sol_Est                             0.554525
# 17:Meteo_Exterior_Sol_Sud                             0.977626
# 18:Meteo_Exterior_Piranometro                         0.942428
# 19:Exterior_Entalpic_1                                     NaN
# 20:Exterior_Entalpic_2                                     NaN
# 21:Exterior_Entalpic_turbo                                 NaN
# 22:Temperature_Exterior_Sensor                        0.374750
# 23:Humedad_Exterior_Sensor                           -0.312982
# 24:Day_Of_Week                                        0.045991
#
#                                  12:Precipitacion  \
# 3:Temperature_Comedor_Sensor            -0.381150
# 4:Temperature_Habitacion_Sensor         -0.367306
# 5:Weather_Temperature                   -0.181613
# 6:CO2_Comedor_Sensor                    -0.156385
# 8:Humedad_Comedor_Sensor                -0.726122
# 9:Humedad_Habitacion_Sensor             -0.295098
# 10:Lighting_Comedor_Sensor              -0.158452
# 11:Lighting_Habitacion_Sensor           -0.167413
# 12:Precipitacion                         1.000000
# 13:Meteo_Exterior_Crepusculo            -0.028986
# 14:Meteo_Exterior_Viento                 0.620606
# 15:Meteo_Exterior_Sol_Oest              -0.157221
# 16:Meteo_Exterior_Sol_Est               -0.161314
# 17:Meteo_Exterior_Sol_Sud               -0.201035
# 18:Meteo_Exterior_Piranometro           -0.199961
# 19:Exterior_Entalpic_1                        NaN
# 20:Exterior_Entalpic_2                        NaN
# 21:Exterior_Entalpic_turbo                    NaN
# 22:Temperature_Exterior_Sensor          -0.328003
# 23:Humedad_Exterior_Sensor               0.495350
# 24:Day_Of_Week                          -0.400037
#
#                                  13:Meteo_Exterior_Crepusculo       ...        \
# 3:Temperature_Comedor_Sensor                         0.074400       ...
# 4:Temperature_Habitacion_Sensor                      0.100660       ...
# 5:Weather_Temperature                                0.445997       ...
# 6:CO2_Comedor_Sensor                                 0.145326       ...
# 8:Humedad_Comedor_Sensor                            -0.174787       ...
# 9:Humedad_Habitacion_Sensor                         -0.314129       ...
# 10:Lighting_Comedor_Sensor                           0.637385       ...
# 11:Lighting_Habitacion_Sensor                        0.623931       ...
# 12:Precipitacion                                    -0.028986       ...
# 13:Meteo_Exterior_Crepusculo                         1.000000       ...
# 14:Meteo_Exterior_Viento                             0.289710       ...
# 15:Meteo_Exterior_Sol_Oest                           0.530884       ...
# 16:Meteo_Exterior_Sol_Est                            0.553657       ...
# 17:Meteo_Exterior_Sol_Sud                            0.664511       ...
# 18:Meteo_Exterior_Piranometro                        0.704723       ...
# 19:Exterior_Entalpic_1                                    NaN       ...
# 20:Exterior_Entalpic_2                                    NaN       ...
# 21:Exterior_Entalpic_turbo                                NaN       ...
# 22:Temperature_Exterior_Sensor                       0.365341       ...
# 23:Humedad_Exterior_Sensor                          -0.310735       ...
# 24:Day_Of_Week                                       0.010429       ...
#
#                                  15:Meteo_Exterior_Sol_Oest  \
# 3:Temperature_Comedor_Sensor                       0.358659
# 4:Temperature_Habitacion_Sensor                    0.385210
# 5:Weather_Temperature                              0.547104
# 6:CO2_Comedor_Sensor                               0.117886
# 8:Humedad_Comedor_Sensor                          -0.037898
# 9:Humedad_Habitacion_Sensor                       -0.166022
# 10:Lighting_Comedor_Sensor                         0.428251
# 11:Lighting_Habitacion_Sensor                      0.316715
# 12:Precipitacion                                  -0.157221
# 13:Meteo_Exterior_Crepusculo                       0.530884
# 14:Meteo_Exterior_Viento                           0.411479
# 15:Meteo_Exterior_Sol_Oest                         1.000000
# 16:Meteo_Exterior_Sol_Est                          0.127826
# 17:Meteo_Exterior_Sol_Sud                          0.426326
# 18:Meteo_Exterior_Piranometro                      0.584981
# 19:Exterior_Entalpic_1                                  NaN
# 20:Exterior_Entalpic_2                                  NaN
# 21:Exterior_Entalpic_turbo                              NaN
# 22:Temperature_Exterior_Sensor                     0.617432
# 23:Humedad_Exterior_Sensor                        -0.434594
# 24:Day_Of_Week                                     0.104175
#
#                                  16:Meteo_Exterior_Sol_Est  \
# 3:Temperature_Comedor_Sensor                     -0.200833
# 4:Temperature_Habitacion_Sensor                  -0.207803
# 5:Weather_Temperature                             0.017039
# 6:CO2_Comedor_Sensor                              0.027292
# 8:Humedad_Comedor_Sensor                          0.009443
# 9:Humedad_Habitacion_Sensor                      -0.178558
# 10:Lighting_Comedor_Sensor                        0.403537
# 11:Lighting_Habitacion_Sensor                     0.554525
# 12:Precipitacion                                 -0.161314
# 13:Meteo_Exterior_Crepusculo                      0.553657
# 14:Meteo_Exterior_Viento                         -0.088620
# 15:Meteo_Exterior_Sol_Oest                        0.127826
# 16:Meteo_Exterior_Sol_Est                         1.000000
# 17:Meteo_Exterior_Sol_Sud                         0.624647
# 18:Meteo_Exterior_Piranometro                     0.503240
# 19:Exterior_Entalpic_1                                 NaN
# 20:Exterior_Entalpic_2                                 NaN
# 21:Exterior_Entalpic_turbo                             NaN
# 22:Temperature_Exterior_Sensor                   -0.084799
# 23:Humedad_Exterior_Sensor                       -0.186347
# 24:Day_Of_Week                                    0.040364
#
#                                  17:Meteo_Exterior_Sol_Sud  \
# 3:Temperature_Comedor_Sensor                      0.063966
# 4:Temperature_Habitacion_Sensor                   0.103537
# 5:Weather_Temperature                             0.521690
# 6:CO2_Comedor_Sensor                              0.296029
# 8:Humedad_Comedor_Sensor                         -0.062619
# 9:Humedad_Habitacion_Sensor                      -0.280088
# 10:Lighting_Comedor_Sensor                        0.949803
# 11:Lighting_Habitacion_Sensor                     0.977626
# 12:Precipitacion                                 -0.201035
# 13:Meteo_Exterior_Crepusculo                      0.664511
# 14:Meteo_Exterior_Viento                          0.276446
# 15:Meteo_Exterior_Sol_Oest                        0.426326
# 16:Meteo_Exterior_Sol_Est                         0.624647
# 17:Meteo_Exterior_Sol_Sud                         1.000000
# 18:Meteo_Exterior_Piranometro                     0.971659
# 19:Exterior_Entalpic_1                                 NaN
# 20:Exterior_Entalpic_2                                 NaN
# 21:Exterior_Entalpic_turbo                             NaN
# 22:Temperature_Exterior_Sensor                    0.396099
# 23:Humedad_Exterior_Sensor                       -0.362942
# 24:Day_Of_Week                                    0.064241
#
#                                  18:Meteo_Exterior_Piranometro  \
# 3:Temperature_Comedor_Sensor                          0.156465
# 4:Temperature_Habitacion_Sensor                       0.201015
# 5:Weather_Temperature                                 0.617818
# 6:CO2_Comedor_Sensor                                  0.306637
# 8:Humedad_Comedor_Sensor                             -0.077746
# 9:Humedad_Habitacion_Sensor                          -0.282370
# 10:Lighting_Comedor_Sensor                            0.960062
# 11:Lighting_Habitacion_Sensor                         0.942428
# 12:Precipitacion                                     -0.199961
# 13:Meteo_Exterior_Crepusculo                          0.704723
# 14:Meteo_Exterior_Viento                              0.361643
# 15:Meteo_Exterior_Sol_Oest                            0.584981
# 16:Meteo_Exterior_Sol_Est                             0.503240
# 17:Meteo_Exterior_Sol_Sud                             0.971659
# 18:Meteo_Exterior_Piranometro                         1.000000
# 19:Exterior_Entalpic_1                                     NaN
# 20:Exterior_Entalpic_2                                     NaN
# 21:Exterior_Entalpic_turbo                                 NaN
# 22:Temperature_Exterior_Sensor                        0.518888
# 23:Humedad_Exterior_Sensor                           -0.409752
# 24:Day_Of_Week                                        0.076199
#
#                                  19:Exterior_Entalpic_1  \
# 3:Temperature_Comedor_Sensor                        NaN
# 4:Temperature_Habitacion_Sensor                     NaN
# 5:Weather_Temperature                               NaN
# 6:CO2_Comedor_Sensor                                NaN
# 8:Humedad_Comedor_Sensor                            NaN
# 9:Humedad_Habitacion_Sensor                         NaN
# 10:Lighting_Comedor_Sensor                          NaN
# 11:Lighting_Habitacion_Sensor                       NaN
# 12:Precipitacion                                    NaN
# 13:Meteo_Exterior_Crepusculo                        NaN
# 14:Meteo_Exterior_Viento                            NaN
# 15:Meteo_Exterior_Sol_Oest                          NaN
# 16:Meteo_Exterior_Sol_Est                           NaN
# 17:Meteo_Exterior_Sol_Sud                           NaN
# 18:Meteo_Exterior_Piranometro                       NaN
# 19:Exterior_Entalpic_1                              NaN
# 20:Exterior_Entalpic_2                              NaN
# 21:Exterior_Entalpic_turbo                          NaN
# 22:Temperature_Exterior_Sensor                      NaN
# 23:Humedad_Exterior_Sensor                          NaN
# 24:Day_Of_Week                                      NaN
#
#                                  20:Exterior_Entalpic_2  \
# 3:Temperature_Comedor_Sensor                        NaN
# 4:Temperature_Habitacion_Sensor                     NaN
# 5:Weather_Temperature                               NaN
# 6:CO2_Comedor_Sensor                                NaN
# 8:Humedad_Comedor_Sensor                            NaN
# 9:Humedad_Habitacion_Sensor                         NaN
# 10:Lighting_Comedor_Sensor                          NaN
# 11:Lighting_Habitacion_Sensor                       NaN
# 12:Precipitacion                                    NaN
# 13:Meteo_Exterior_Crepusculo                        NaN
# 14:Meteo_Exterior_Viento                            NaN
# 15:Meteo_Exterior_Sol_Oest                          NaN
# 16:Meteo_Exterior_Sol_Est                           NaN
# 17:Meteo_Exterior_Sol_Sud                           NaN
# 18:Meteo_Exterior_Piranometro                       NaN
# 19:Exterior_Entalpic_1                              NaN
# 20:Exterior_Entalpic_2                              NaN
# 21:Exterior_Entalpic_turbo                          NaN
# 22:Temperature_Exterior_Sensor                      NaN
# 23:Humedad_Exterior_Sensor                          NaN
# 24:Day_Of_Week                                      NaN
#
#                                  21:Exterior_Entalpic_turbo  \
# 3:Temperature_Comedor_Sensor                            NaN
# 4:Temperature_Habitacion_Sensor                         NaN
# 5:Weather_Temperature                                   NaN
# 6:CO2_Comedor_Sensor                                    NaN
# 8:Humedad_Comedor_Sensor                                NaN
# 9:Humedad_Habitacion_Sensor                             NaN
# 10:Lighting_Comedor_Sensor                              NaN
# 11:Lighting_Habitacion_Sensor                           NaN
# 12:Precipitacion                                        NaN
# 13:Meteo_Exterior_Crepusculo                            NaN
# 14:Meteo_Exterior_Viento                                NaN
# 15:Meteo_Exterior_Sol_Oest                              NaN
# 16:Meteo_Exterior_Sol_Est                               NaN
# 17:Meteo_Exterior_Sol_Sud                               NaN
# 18:Meteo_Exterior_Piranometro                           NaN
# 19:Exterior_Entalpic_1                                  NaN
# 20:Exterior_Entalpic_2                                  NaN
# 21:Exterior_Entalpic_turbo                              NaN
# 22:Temperature_Exterior_Sensor                          NaN
# 23:Humedad_Exterior_Sensor                              NaN
# 24:Day_Of_Week                                          NaN
#
#                                  22:Temperature_Exterior_Sensor  \
# 3:Temperature_Comedor_Sensor                           0.863681
# 4:Temperature_Habitacion_Sensor                        0.886487
# 5:Weather_Temperature                                  0.944728
# 6:CO2_Comedor_Sensor                                   0.259769
# 8:Humedad_Comedor_Sensor                               0.220221
# 9:Humedad_Habitacion_Sensor                           -0.257254
# 10:Lighting_Comedor_Sensor                             0.463075
# 11:Lighting_Habitacion_Sensor                          0.374750
# 12:Precipitacion                                      -0.328003
# 13:Meteo_Exterior_Crepusculo                           0.365341
# 14:Meteo_Exterior_Viento                               0.171339
# 15:Meteo_Exterior_Sol_Oest                             0.617432
# 16:Meteo_Exterior_Sol_Est                             -0.084799
# 17:Meteo_Exterior_Sol_Sud                              0.396099
# 18:Meteo_Exterior_Piranometro                          0.518888
# 19:Exterior_Entalpic_1                                      NaN
# 20:Exterior_Entalpic_2                                      NaN
# 21:Exterior_Entalpic_turbo                                  NaN
# 22:Temperature_Exterior_Sensor                         1.000000
# 23:Humedad_Exterior_Sensor                            -0.662438
# 24:Day_Of_Week                                         0.390574
#
#                                  23:Humedad_Exterior_Sensor  24:Day_Of_Week
# 3:Temperature_Comedor_Sensor                      -0.701744        0.487941
# 4:Temperature_Habitacion_Sensor                   -0.691107        0.475587
# 5:Weather_Temperature                             -0.559645        0.292084
# 6:CO2_Comedor_Sensor                              -0.240730       -0.150782
# 8:Humedad_Comedor_Sensor                          -0.180180        0.359899
# 9:Humedad_Habitacion_Sensor                        0.564098       -0.005104
# 10:Lighting_Comedor_Sensor                        -0.331583        0.051751
# 11:Lighting_Habitacion_Sensor                     -0.312982        0.045991
# 12:Precipitacion                                   0.495350       -0.400037
# 13:Meteo_Exterior_Crepusculo                      -0.310735        0.010429
# 14:Meteo_Exterior_Viento                           0.145189       -0.306007
# 15:Meteo_Exterior_Sol_Oest                        -0.434594        0.104175
# 16:Meteo_Exterior_Sol_Est                         -0.186347        0.040364
# 17:Meteo_Exterior_Sol_Sud                         -0.362942        0.064241
# 18:Meteo_Exterior_Piranometro                     -0.409752        0.076199
# 19:Exterior_Entalpic_1                                  NaN             NaN
# 20:Exterior_Entalpic_2                                  NaN             NaN
# 21:Exterior_Entalpic_turbo                              NaN             NaN
# 22:Temperature_Exterior_Sensor                    -0.662438        0.390574
# 23:Humedad_Exterior_Sensor                         1.000000       -0.344881
# 24:Day_Of_Week                                    -0.344881        1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# Analyzing the data, we decide to futher investigate the correlation among indoor temperature, outdoor temperature, solar irradiance (measured by a piranometer) and inside lighting

# %%
# building a normalized dataframe and adding subplots in order to show the correlation graphically 
Normalized_DF=DF_cleaned.copy()

# removing not correlated columns
Normalized_DF.drop(Normalized_DF.columns[[0,1,10,11,12,13,14,15,17,18,19,22,23]],axis=1,inplace=True) 

# normalizing
Max = Normalized_DF.max() 
Min = Normalized_DF.min()
Normalized_DF= (Normalized_DF-Min)/(Max-Min)

fig = plt.figure()
ax1= fig.add_subplot(3,1,1) 
ax2= fig.add_subplot(3,1,2)
ax3= fig.add_subplot(3,1,3)

Normalized_DF["18:Meteo_Exterior_Piranometro"].plot(ax=ax1,color= "g", legend= True)
Normalized_DF["5:Weather_Temperature"].plot(ax=ax1,color= "y", legend= True)
Normalized_DF["22:Temperature_Exterior_Sensor"].plot(ax=ax2,color= "r", legend= True)
Normalized_DF["4:Temperature_Habitacion_Sensor"].plot(ax=ax2,color= "k", legend= True)
Normalized_DF["10:Lighting_Comedor_Sensor"].plot(ax=ax3,color= "b", legend= True)
Normalized_DF["11:Lighting_Habitacion_Sensor"].plot(ax=ax3,color= "c", legend= True)
plt.show()

# %% [markdown]
# From this graph we can observe that there is a delay between solar irradiance and both temperatures

# %% [markdown]
# Now we define some functions useful for the analysis

# %%
# defining a function which calculates the lag, generate columns with a delay of time and save them in a new dataframe
DF_FinalDataSet= DF_cleaned.copy()

def lag_column(df,column_name,lag_period=1):
    for i in range(1,lag_period+1,1):
        new_column_name= column_name+"-"+str(i)+"hr"
        df[new_column_name]= df[column_name].shift(i)
  
    return df

DF_FinalDataSet= lag_column(DF_FinalDataSet,"4:Temperature_Habitacion_Sensor",24)
DF_FinalDataSet.dropna(inplace=True)

# %%
#definition of function determining if the day is a weekend day 
def weekendDetector(day):
    weekendLabel=0
    if (day== 5or day==6):
        weekendLabel=1
    else:
        weekendLabel=0
    return weekendLabel   #if I get 1 it's a weekend day
  
#definition of function determining if the day is a weekend day     
def dayDetector(hour):
    dayLabel=1
    if(hour<20 and hour>9):
        dayLabel=1
    else:
        dayLabel=0
    return dayLabel      #if I get 1 it's day (from 9 to 20)

# %% [markdown]
# Now we add the corresponding columns to dataframe

# %%
DF_FinalDataSet["weekend"] = [weekendDetector(thisDay) for thisDay in DF_FinalDataSet.index.dayofweek]   
DF_FinalDataSet["day_night"] = [dayDetector(thisHour) for thisHour in DF_FinalDataSet.index.hour] 
DF_FinalDataSet.head()  
DF_FinalDataSet.dropna(inplace=True)

# %% [markdown]
# We apply the shift to the indoor temperature, because it is the parameter which presents a delay w.r.t. the solar irradiance

# %%
# removing the columns which we do not include in the model 
DF_FinalDataSet.drop(DF_FinalDataSet.columns[[0,1,6,8,9,10,11,12,13,14,15,17,18,19,23]],axis=1,inplace=True);
DF_FinalDataSet.dropna(inplace=True)    
DF_FinalDataSet.corr()

# splitting the data in two different dataframe
# DF_target contains the parameter that we want to predict, DF_features is the original dataframe without the target column 
DF_target = DF_FinalDataSet["4:Temperature_Habitacion_Sensor"]
DF_features = DF_FinalDataSet.drop("4:Temperature_Habitacion_Sensor", axis = 1)

# now that we have input(features) and output(target) we can build the model
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(DF_features,DF_target,test_size=0.2,random_state=41234)

# %% [markdown]
# The test_size represents the percentage of data used for testing, in our case 20% for testing while 80% for checking

# %%
# testing the model
from sklearn import linear_model
linear_reg = linear_model.LinearRegression()

# %%
# defining the linear model with training data (20%)
linear_reg.fit(X_train,Y_train)

# testing the plot with the other checking data (80%)
predict_linearReg_split = linear_reg.predict(X_test)

#collecting them in a dataframe
Y_test.index
predict_DF_linearReg_split = pd.DataFrame(predict_linearReg_split,index = Y_test.index,columns = ["TempPredict_LinReg"])
predict_DF_linearReg_split = predict_DF_linearReg_split.join(Y_test)
predict_DF_linearReg_split_ChosenDates = predict_DF_linearReg_split["2012-03-20":"2012-03-26"]

predict_DF_linearReg_split_ChosenDates.plot()
plt.xlabel("time")
plt.ylabel("temperature")
plt.title("Linear Regression Prediction")
plt.show()

# %%
# finding the metrics related to linear regression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mean_absolute_error_linearReg_split = mean_absolute_error(Y_test,predict_linearReg_split)
mean_squared_error_linearReg_split = mean_squared_error(Y_test,predict_linearReg_split)
R2_score_linearReg_split = r2_score(Y_test,predict_linearReg_split)

print 'Coefficient of determination (R-squared) = '+str(R2_score_linearReg_split)
# Out:
# Coefficient of determination (R-squared) = 0.999493419422

# %%
# using another method called cross validation
from sklearn.model_selection import cross_val_predict
predict_linearReg_CV = cross_val_predict(linear_reg,DF_features,DF_target,cv=10)
predict_DF_linearReg_CV = pd.DataFrame(predict_linearReg_CV,index = DF_target.index,columns = ["TempPredict_CrossVal"])
predict_DF_linearReg_CV = predict_DF_linearReg_CV.join(DF_target)
predict_DF_linearReg_CV_ChosenDates = predict_DF_linearReg_CV["2012-03-20 12:00:00 ":"2012-03-26 12:00:00"]
predict_DF_linearReg_CV_ChosenDates.plot()
plt.xlabel("time")
plt.ylabel("temperature")
plt.title("Cross Validation Prediction")
plt.show(1)

# %%
# finding the metrics related to cross validation 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mean_absolute_error_linearReg_CV = mean_absolute_error(DF_target,predict_linearReg_CV)
mean_squared_error_linearReg_CV = mean_squared_error(DF_target,predict_linearReg_CV)
R2_score_linearReg_CV = r2_score(DF_target,predict_linearReg_CV)
print 'Coefficient of determination (R-squared) = '+str(R2_score_linearReg_CV)
# Out:
# Coefficient of determination (R-squared) = 0.999427894156

# %%
# one more prediction model: random forest regressor
from sklearn.ensemble import RandomForestRegressor
reg_RF = RandomForestRegressor()
predict_RF_CV = cross_val_predict(reg_RF,DF_features,DF_target,cv=10)
predict_DF_RF_CV = pd.DataFrame(predict_RF_CV,index = DF_target.index,columns = ["TempPredict_RandomFor"])
predict_DF_RF_CV = predict_DF_RF_CV.join(DF_target)
predict_DF_RF_CV_ChosenDates = predict_DF_RF_CV["2012-03-20 12:00:00 ":"2012-03-26 12:00:00"]
predict_DF_RF_CV_ChosenDates.plot()
plt.xlabel("time")
plt.ylabel("temperature")
plt.show()

# %%
#finding the metrics related to random forest regressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mean_absolute_error_linearReg_RF = mean_absolute_error(DF_target,predict_RF_CV)
mean_squared_error_linearReg_RF = mean_squared_error(DF_target,predict_RF_CV)
R2_score_linearReg_RF = r2_score(DF_target,predict_RF_CV)
print 'Coefficient of determination (R-squared) = '+str(R2_score_linearReg_RF)
# Out:
# Coefficient of determination (R-squared) = 0.982838107455

# %% [markdown]
# # Conclusion
# We can point out that both models turn to be a good approximation of the actual values behaviour. In particular, the linear regression is the model which reaches higher R-Squared showing to be the best fit.
