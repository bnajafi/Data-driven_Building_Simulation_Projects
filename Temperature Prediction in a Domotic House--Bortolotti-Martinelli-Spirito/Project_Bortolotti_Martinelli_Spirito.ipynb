# %% [markdown]
# # Data driven building simulation
#
# In this learning-machine code, we are using data taken from paper: "On-line learning of indoor temperature forecasting models towards energy efficiency".
# This dataset is collected from a monitor system settled in a domotic house near Valencia, built by Cardinal Herrera University. It corresponds to approximately 40 days of monitoring data, which are sampled every 15 minutes.
# The first aim of the project is to investigate the correlation between outside and inside parameters. Then we proceed with the building of a model in order to predict the indoor temperature variation as a function of all the other data which are related to it.

# %%
#importing dataset 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DataFolderPath = "C:\Users\giugi\Dropbox\Building systems group project\Project\DataDriven"
FileName= "NEW-DATA-1.T15.txt"
FilePath = DataFolderPath+"\\"+FileName

# combining first and second columns to create a unique index column (date+time)
DataFrame = pd.read_csv(FilePath, sep= " ", index_col=6)
DataFrame["period"] = DataFrame["1:Date"].map(str) + " " + DataFrame["2:Time"].map(str)
DataFrame.index = DataFrame["period"]

# %%
# convert indexes from dtype 'object' to 'datetime'
previousIndex = DataFrame.index 
ParsedIndex = pd.to_datetime(previousIndex)
DataFrame.index = ParsedIndex

# %%
# selecting a specific time interval and removing the NaNs
DF_myChosenDates = DataFrame["2012-03-20 12:00:00 ":"2012-03-23 12:00:00 "]
DF_cleaned = DF_myChosenDates.dropna()

# %%
# looking for a correlation among data 
DF_cleaned.corr()
# Out:
#                                  3:Temperature_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                         1.000000
# 4:Temperature_Habitacion_Sensor                      0.991750
# 5:Weather_Temperature                                0.738386
# 6:CO2_Comedor_Sensor                                 0.697682
# 8:Humedad_Comedor_Sensor                             0.352276
# 9:Humedad_Habitacion_Sensor                         -0.201960
# 10:Lighting_Comedor_Sensor                           0.203087
# 11:Lighting_Habitacion_Sensor                        0.120177
# 12:Precipitacion                                    -0.319768
# 13:Meteo_Exterior_Crepusculo                         0.130975
# 14:Meteo_Exterior_Viento                            -0.085751
# 15:Meteo_Exterior_Sol_Oest                           0.496972
# 16:Meteo_Exterior_Sol_Est                           -0.190735
# 17:Meteo_Exterior_Sol_Sud                            0.157812
# 18:Meteo_Exterior_Piranometro                        0.248869
# 19:Exterior_Entalpic_1                                    NaN
# 20:Exterior_Entalpic_2                                    NaN
# 21:Exterior_Entalpic_turbo                                NaN
# 22:Temperature_Exterior_Sensor                       0.885960
# 23:Humedad_Exterior_Sensor                          -0.693552
# 24:Day_Of_Week                                       0.328668
#
#                                  4:Temperature_Habitacion_Sensor  \
# 3:Temperature_Comedor_Sensor                            0.991750
# 4:Temperature_Habitacion_Sensor                         1.000000
# 5:Weather_Temperature                                   0.772518
# 6:CO2_Comedor_Sensor                                    0.730511
# 8:Humedad_Comedor_Sensor                                0.329334
# 9:Humedad_Habitacion_Sensor                            -0.192619
# 10:Lighting_Comedor_Sensor                              0.272777
# 11:Lighting_Habitacion_Sensor                           0.179446
# 12:Precipitacion                                       -0.299455
# 13:Meteo_Exterior_Crepusculo                            0.170408
# 14:Meteo_Exterior_Viento                               -0.034230
# 15:Meteo_Exterior_Sol_Oest                              0.533660
# 16:Meteo_Exterior_Sol_Est                              -0.197513
# 17:Meteo_Exterior_Sol_Sud                               0.215976
# 18:Meteo_Exterior_Piranometro                           0.313047
# 19:Exterior_Entalpic_1                                       NaN
# 20:Exterior_Entalpic_2                                       NaN
# 21:Exterior_Entalpic_turbo                                   NaN
# 22:Temperature_Exterior_Sensor                          0.912772
# 23:Humedad_Exterior_Sensor                             -0.661631
# 24:Day_Of_Week                                          0.275542
#
#                                  5:Weather_Temperature  6:CO2_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                  0.738386              0.697682
# 4:Temperature_Habitacion_Sensor               0.772518              0.730511
# 5:Weather_Temperature                         1.000000              0.590256
# 6:CO2_Comedor_Sensor                          0.590256              1.000000
# 8:Humedad_Comedor_Sensor                      0.094413              0.424924
# 9:Humedad_Habitacion_Sensor                  -0.197850              0.081113
# 10:Lighting_Comedor_Sensor                    0.637744              0.433529
# 11:Lighting_Habitacion_Sensor                 0.580487              0.354848
# 12:Precipitacion                             -0.159738             -0.529536
# 13:Meteo_Exterior_Crepusculo                  0.415530              0.308183
# 14:Meteo_Exterior_Viento                      0.258786             -0.113615
# 15:Meteo_Exterior_Sol_Oest                    0.553761              0.662112
# 16:Meteo_Exterior_Sol_Est                     0.052539              0.038009
# 17:Meteo_Exterior_Sol_Sud                     0.587032              0.422184
# 18:Meteo_Exterior_Piranometro                 0.657693              0.515601
# 19:Exterior_Entalpic_1                             NaN                   NaN
# 20:Exterior_Entalpic_2                             NaN                   NaN
# 21:Exterior_Entalpic_turbo                         NaN                   NaN
# 22:Temperature_Exterior_Sensor                0.924586              0.755949
# 23:Humedad_Exterior_Sensor                   -0.491271             -0.553412
# 24:Day_Of_Week                                0.043823              0.342202
#
#                                  8:Humedad_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                     0.352276
# 4:Temperature_Habitacion_Sensor                  0.329334
# 5:Weather_Temperature                            0.094413
# 6:CO2_Comedor_Sensor                             0.424924
# 8:Humedad_Comedor_Sensor                         1.000000
# 9:Humedad_Habitacion_Sensor                      0.644086
# 10:Lighting_Comedor_Sensor                      -0.031951
# 11:Lighting_Habitacion_Sensor                   -0.007426
# 12:Precipitacion                                -0.765073
# 13:Meteo_Exterior_Crepusculo                    -0.112723
# 14:Meteo_Exterior_Viento                        -0.689490
# 15:Meteo_Exterior_Sol_Oest                       0.035241
# 16:Meteo_Exterior_Sol_Est                        0.093447
# 17:Meteo_Exterior_Sol_Sud                        0.019114
# 18:Meteo_Exterior_Piranometro                    0.005361
# 19:Exterior_Entalpic_1                                NaN
# 20:Exterior_Entalpic_2                                NaN
# 21:Exterior_Entalpic_turbo                            NaN
# 22:Temperature_Exterior_Sensor                   0.278896
# 23:Humedad_Exterior_Sensor                      -0.330180
# 24:Day_Of_Week                                   0.445719
#
#                                  9:Humedad_Habitacion_Sensor  \
# 3:Temperature_Comedor_Sensor                       -0.201960
# 4:Temperature_Habitacion_Sensor                    -0.192619
# 5:Weather_Temperature                              -0.197850
# 6:CO2_Comedor_Sensor                                0.081113
# 8:Humedad_Comedor_Sensor                            0.644086
# 9:Humedad_Habitacion_Sensor                         1.000000
# 10:Lighting_Comedor_Sensor                         -0.177236
# 11:Lighting_Habitacion_Sensor                      -0.175222
# 12:Precipitacion                                   -0.473744
# 13:Meteo_Exterior_Crepusculo                       -0.261758
# 14:Meteo_Exterior_Viento                           -0.403084
# 15:Meteo_Exterior_Sol_Oest                         -0.102857
# 16:Meteo_Exterior_Sol_Est                          -0.094465
# 17:Meteo_Exterior_Sol_Sud                          -0.168137
# 18:Meteo_Exterior_Piranometro                      -0.167205
# 19:Exterior_Entalpic_1                                   NaN
# 20:Exterior_Entalpic_2                                   NaN
# 21:Exterior_Entalpic_turbo                               NaN
# 22:Temperature_Exterior_Sensor                     -0.125370
# 23:Humedad_Exterior_Sensor                          0.389492
# 24:Day_Of_Week                                     -0.095753
#
#                                  10:Lighting_Comedor_Sensor  \
# 3:Temperature_Comedor_Sensor                       0.203087
# 4:Temperature_Habitacion_Sensor                    0.272777
# 5:Weather_Temperature                              0.637744
# 6:CO2_Comedor_Sensor                               0.433529
# 8:Humedad_Comedor_Sensor                          -0.031951
# 9:Humedad_Habitacion_Sensor                       -0.177236
# 10:Lighting_Comedor_Sensor                         1.000000
# 11:Lighting_Habitacion_Sensor                      0.958805
# 12:Precipitacion                                  -0.222386
# 13:Meteo_Exterior_Crepusculo                       0.616067
# 14:Meteo_Exterior_Viento                           0.204706
# 15:Meteo_Exterior_Sol_Oest                         0.418389
# 16:Meteo_Exterior_Sol_Est                          0.402148
# 17:Meteo_Exterior_Sol_Sud                          0.950155
# 18:Meteo_Exterior_Piranometro                      0.959486
# 19:Exterior_Entalpic_1                                  NaN
# 20:Exterior_Entalpic_2                                  NaN
# 21:Exterior_Entalpic_turbo                              NaN
# 22:Temperature_Exterior_Sensor                     0.532368
# 23:Humedad_Exterior_Sensor                        -0.338371
# 24:Day_Of_Week                                     0.173256
#
#                                  11:Lighting_Habitacion_Sensor  \
# 3:Temperature_Comedor_Sensor                          0.120177
# 4:Temperature_Habitacion_Sensor                       0.179446
# 5:Weather_Temperature                                 0.580487
# 6:CO2_Comedor_Sensor                                  0.354848
# 8:Humedad_Comedor_Sensor                             -0.007426
# 9:Humedad_Habitacion_Sensor                          -0.175222
# 10:Lighting_Comedor_Sensor                            0.958805
# 11:Lighting_Habitacion_Sensor                         1.000000
# 12:Precipitacion                                     -0.234285
# 13:Meteo_Exterior_Crepusculo                          0.599654
# 14:Meteo_Exterior_Viento                              0.136879
# 15:Meteo_Exterior_Sol_Oest                            0.309928
# 16:Meteo_Exterior_Sol_Est                             0.548663
# 17:Meteo_Exterior_Sol_Sud                             0.974723
# 18:Meteo_Exterior_Piranometro                         0.941709
# 19:Exterior_Entalpic_1                                     NaN
# 20:Exterior_Entalpic_2                                     NaN
# 21:Exterior_Entalpic_turbo                                 NaN
# 22:Temperature_Exterior_Sensor                        0.441651
# 23:Humedad_Exterior_Sensor                           -0.335234
# 24:Day_Of_Week                                        0.233873
#
#                                  12:Precipitacion  \
# 3:Temperature_Comedor_Sensor            -0.319768
# 4:Temperature_Habitacion_Sensor         -0.299455
# 5:Weather_Temperature                   -0.159738
# 6:CO2_Comedor_Sensor                    -0.529536
# 8:Humedad_Comedor_Sensor                -0.765073
# 9:Humedad_Habitacion_Sensor             -0.473744
# 10:Lighting_Comedor_Sensor              -0.222386
# 11:Lighting_Habitacion_Sensor           -0.234285
# 12:Precipitacion                         1.000000
# 13:Meteo_Exterior_Crepusculo            -0.038282
# 14:Meteo_Exterior_Viento                 0.681744
# 15:Meteo_Exterior_Sol_Oest              -0.216520
# 16:Meteo_Exterior_Sol_Est               -0.217957
# 17:Meteo_Exterior_Sol_Sud               -0.277528
# 18:Meteo_Exterior_Piranometro           -0.275680
# 19:Exterior_Entalpic_1                        NaN
# 20:Exterior_Entalpic_2                        NaN
# 21:Exterior_Entalpic_turbo                    NaN
# 22:Temperature_Exterior_Sensor          -0.345110
# 23:Humedad_Exterior_Sensor               0.501221
# 24:Day_Of_Week                          -0.702339
#
#                                  13:Meteo_Exterior_Crepusculo       ...        \
# 3:Temperature_Comedor_Sensor                         0.130975       ...
# 4:Temperature_Habitacion_Sensor                      0.170408       ...
# 5:Weather_Temperature                                0.415530       ...
# 6:CO2_Comedor_Sensor                                 0.308183       ...
# 8:Humedad_Comedor_Sensor                            -0.112723       ...
# 9:Humedad_Habitacion_Sensor                         -0.261758       ...
# 10:Lighting_Comedor_Sensor                           0.616067       ...
# 11:Lighting_Habitacion_Sensor                        0.599654       ...
# 12:Precipitacion                                    -0.038282       ...
# 13:Meteo_Exterior_Crepusculo                         1.000000       ...
# 14:Meteo_Exterior_Viento                             0.146794       ...
# 15:Meteo_Exterior_Sol_Oest                           0.499403       ...
# 16:Meteo_Exterior_Sol_Est                            0.516618       ...
# 17:Meteo_Exterior_Sol_Sud                            0.627136       ...
# 18:Meteo_Exterior_Piranometro                        0.667412       ...
# 19:Exterior_Entalpic_1                                    NaN       ...
# 20:Exterior_Entalpic_2                                    NaN       ...
# 21:Exterior_Entalpic_turbo                                NaN       ...
# 22:Temperature_Exterior_Sensor                       0.374037       ...
# 23:Humedad_Exterior_Sensor                          -0.235143       ...
# 24:Day_Of_Week                                       0.016845       ...
#
#                                  15:Meteo_Exterior_Sol_Oest  \
# 3:Temperature_Comedor_Sensor                       0.496972
# 4:Temperature_Habitacion_Sensor                    0.533660
# 5:Weather_Temperature                              0.553761
# 6:CO2_Comedor_Sensor                               0.662112
# 8:Humedad_Comedor_Sensor                           0.035241
# 9:Humedad_Habitacion_Sensor                       -0.102857
# 10:Lighting_Comedor_Sensor                         0.418389
# 11:Lighting_Habitacion_Sensor                      0.309928
# 12:Precipitacion                                  -0.216520
# 13:Meteo_Exterior_Crepusculo                       0.499403
# 14:Meteo_Exterior_Viento                           0.267195
# 15:Meteo_Exterior_Sol_Oest                         1.000000
# 16:Meteo_Exterior_Sol_Est                          0.123516
# 17:Meteo_Exterior_Sol_Sud                          0.439021
# 18:Meteo_Exterior_Piranometro                      0.583333
# 19:Exterior_Entalpic_1                                  NaN
# 20:Exterior_Entalpic_2                                  NaN
# 21:Exterior_Entalpic_turbo                              NaN
# 22:Temperature_Exterior_Sensor                     0.692746
# 23:Humedad_Exterior_Sensor                        -0.430849
# 24:Day_Of_Week                                     0.064335
#
#                                  16:Meteo_Exterior_Sol_Est  \
# 3:Temperature_Comedor_Sensor                     -0.190735
# 4:Temperature_Habitacion_Sensor                  -0.197513
# 5:Weather_Temperature                             0.052539
# 6:CO2_Comedor_Sensor                              0.038009
# 8:Humedad_Comedor_Sensor                          0.093447
# 9:Humedad_Habitacion_Sensor                      -0.094465
# 10:Lighting_Comedor_Sensor                        0.402148
# 11:Lighting_Habitacion_Sensor                     0.548663
# 12:Precipitacion                                 -0.217957
# 13:Meteo_Exterior_Crepusculo                      0.516618
# 14:Meteo_Exterior_Viento                         -0.127935
# 15:Meteo_Exterior_Sol_Oest                        0.123516
# 16:Meteo_Exterior_Sol_Est                         1.000000
# 17:Meteo_Exterior_Sol_Sud                         0.610834
# 18:Meteo_Exterior_Piranometro                     0.497570
# 19:Exterior_Entalpic_1                                 NaN
# 20:Exterior_Entalpic_2                                 NaN
# 21:Exterior_Entalpic_turbo                             NaN
# 22:Temperature_Exterior_Sensor                   -0.043018
# 23:Humedad_Exterior_Sensor                       -0.253164
# 24:Day_Of_Week                                    0.353174
#
#                                  17:Meteo_Exterior_Sol_Sud  \
# 3:Temperature_Comedor_Sensor                      0.157812
# 4:Temperature_Habitacion_Sensor                   0.215976
# 5:Weather_Temperature                             0.587032
# 6:CO2_Comedor_Sensor                              0.422184
# 8:Humedad_Comedor_Sensor                          0.019114
# 9:Humedad_Habitacion_Sensor                      -0.168137
# 10:Lighting_Comedor_Sensor                        0.950155
# 11:Lighting_Habitacion_Sensor                     0.974723
# 12:Precipitacion                                 -0.277528
# 13:Meteo_Exterior_Crepusculo                      0.627136
# 14:Meteo_Exterior_Viento                          0.144276
# 15:Meteo_Exterior_Sol_Oest                        0.439021
# 16:Meteo_Exterior_Sol_Est                         0.610834
# 17:Meteo_Exterior_Sol_Sud                         1.000000
# 18:Meteo_Exterior_Piranometro                     0.974163
# 19:Exterior_Entalpic_1                                 NaN
# 20:Exterior_Entalpic_2                                 NaN
# 21:Exterior_Entalpic_turbo                             NaN
# 22:Temperature_Exterior_Sensor                    0.484169
# 23:Humedad_Exterior_Sensor                       -0.400390
# 24:Day_Of_Week                                    0.275979
#
#                                  18:Meteo_Exterior_Piranometro  \
# 3:Temperature_Comedor_Sensor                          0.248869
# 4:Temperature_Habitacion_Sensor                       0.313047
# 5:Weather_Temperature                                 0.657693
# 6:CO2_Comedor_Sensor                                  0.515601
# 8:Humedad_Comedor_Sensor                              0.005361
# 9:Humedad_Habitacion_Sensor                          -0.167205
# 10:Lighting_Comedor_Sensor                            0.959486
# 11:Lighting_Habitacion_Sensor                         0.941709
# 12:Precipitacion                                     -0.275680
# 13:Meteo_Exterior_Crepusculo                          0.667412
# 14:Meteo_Exterior_Viento                              0.200318
# 15:Meteo_Exterior_Sol_Oest                            0.583333
# 16:Meteo_Exterior_Sol_Est                             0.497570
# 17:Meteo_Exterior_Sol_Sud                             0.974163
# 18:Meteo_Exterior_Piranometro                         1.000000
# 19:Exterior_Entalpic_1                                     NaN
# 20:Exterior_Entalpic_2                                     NaN
# 21:Exterior_Entalpic_turbo                                 NaN
# 22:Temperature_Exterior_Sensor                        0.589614
# 23:Humedad_Exterior_Sensor                           -0.415065
# 24:Day_Of_Week                                        0.216753
#
#                                  19:Exterior_Entalpic_1  \
# 3:Temperature_Comedor_Sensor                        NaN
# 4:Temperature_Habitacion_Sensor                     NaN
# 5:Weather_Temperature                               NaN
# 6:CO2_Comedor_Sensor                                NaN
# 8:Humedad_Comedor_Sensor                            NaN
# 9:Humedad_Habitacion_Sensor                         NaN
# 10:Lighting_Comedor_Sensor                          NaN
# 11:Lighting_Habitacion_Sensor                       NaN
# 12:Precipitacion                                    NaN
# 13:Meteo_Exterior_Crepusculo                        NaN
# 14:Meteo_Exterior_Viento                            NaN
# 15:Meteo_Exterior_Sol_Oest                          NaN
# 16:Meteo_Exterior_Sol_Est                           NaN
# 17:Meteo_Exterior_Sol_Sud                           NaN
# 18:Meteo_Exterior_Piranometro                       NaN
# 19:Exterior_Entalpic_1                              NaN
# 20:Exterior_Entalpic_2                              NaN
# 21:Exterior_Entalpic_turbo                          NaN
# 22:Temperature_Exterior_Sensor                      NaN
# 23:Humedad_Exterior_Sensor                          NaN
# 24:Day_Of_Week                                      NaN
#
#                                  20:Exterior_Entalpic_2  \
# 3:Temperature_Comedor_Sensor                        NaN
# 4:Temperature_Habitacion_Sensor                     NaN
# 5:Weather_Temperature                               NaN
# 6:CO2_Comedor_Sensor                                NaN
# 8:Humedad_Comedor_Sensor                            NaN
# 9:Humedad_Habitacion_Sensor                         NaN
# 10:Lighting_Comedor_Sensor                          NaN
# 11:Lighting_Habitacion_Sensor                       NaN
# 12:Precipitacion                                    NaN
# 13:Meteo_Exterior_Crepusculo                        NaN
# 14:Meteo_Exterior_Viento                            NaN
# 15:Meteo_Exterior_Sol_Oest                          NaN
# 16:Meteo_Exterior_Sol_Est                           NaN
# 17:Meteo_Exterior_Sol_Sud                           NaN
# 18:Meteo_Exterior_Piranometro                       NaN
# 19:Exterior_Entalpic_1                              NaN
# 20:Exterior_Entalpic_2                              NaN
# 21:Exterior_Entalpic_turbo                          NaN
# 22:Temperature_Exterior_Sensor                      NaN
# 23:Humedad_Exterior_Sensor                          NaN
# 24:Day_Of_Week                                      NaN
#
#                                  21:Exterior_Entalpic_turbo  \
# 3:Temperature_Comedor_Sensor                            NaN
# 4:Temperature_Habitacion_Sensor                         NaN
# 5:Weather_Temperature                                   NaN
# 6:CO2_Comedor_Sensor                                    NaN
# 8:Humedad_Comedor_Sensor                                NaN
# 9:Humedad_Habitacion_Sensor                             NaN
# 10:Lighting_Comedor_Sensor                              NaN
# 11:Lighting_Habitacion_Sensor                           NaN
# 12:Precipitacion                                        NaN
# 13:Meteo_Exterior_Crepusculo                            NaN
# 14:Meteo_Exterior_Viento                                NaN
# 15:Meteo_Exterior_Sol_Oest                              NaN
# 16:Meteo_Exterior_Sol_Est                               NaN
# 17:Meteo_Exterior_Sol_Sud                               NaN
# 18:Meteo_Exterior_Piranometro                           NaN
# 19:Exterior_Entalpic_1                                  NaN
# 20:Exterior_Entalpic_2                                  NaN
# 21:Exterior_Entalpic_turbo                              NaN
# 22:Temperature_Exterior_Sensor                          NaN
# 23:Humedad_Exterior_Sensor                              NaN
# 24:Day_Of_Week                                          NaN
#
#                                  22:Temperature_Exterior_Sensor  \
# 3:Temperature_Comedor_Sensor                           0.885960
# 4:Temperature_Habitacion_Sensor                        0.912772
# 5:Weather_Temperature                                  0.924586
# 6:CO2_Comedor_Sensor                                   0.755949
# 8:Humedad_Comedor_Sensor                               0.278896
# 9:Humedad_Habitacion_Sensor                           -0.125370
# 10:Lighting_Comedor_Sensor                             0.532368
# 11:Lighting_Habitacion_Sensor                          0.441651
# 12:Precipitacion                                      -0.345110
# 13:Meteo_Exterior_Crepusculo                           0.374037
# 14:Meteo_Exterior_Viento                               0.090766
# 15:Meteo_Exterior_Sol_Oest                             0.692746
# 16:Meteo_Exterior_Sol_Est                             -0.043018
# 17:Meteo_Exterior_Sol_Sud                              0.484169
# 18:Meteo_Exterior_Piranometro                          0.589614
# 19:Exterior_Entalpic_1                                      NaN
# 20:Exterior_Entalpic_2                                      NaN
# 21:Exterior_Entalpic_turbo                                  NaN
# 22:Temperature_Exterior_Sensor                         1.000000
# 23:Humedad_Exterior_Sensor                            -0.635860
# 24:Day_Of_Week                                         0.192651
#
#                                  23:Humedad_Exterior_Sensor  24:Day_Of_Week
# 3:Temperature_Comedor_Sensor                      -0.693552        0.328668
# 4:Temperature_Habitacion_Sensor                   -0.661631        0.275542
# 5:Weather_Temperature                             -0.491271        0.043823
# 6:CO2_Comedor_Sensor                              -0.553412        0.342202
# 8:Humedad_Comedor_Sensor                          -0.330180        0.445719
# 9:Humedad_Habitacion_Sensor                        0.389492       -0.095753
# 10:Lighting_Comedor_Sensor                        -0.338371        0.173256
# 11:Lighting_Habitacion_Sensor                     -0.335234        0.233873
# 12:Precipitacion                                   0.501221       -0.702339
# 13:Meteo_Exterior_Crepusculo                      -0.235143        0.016845
# 14:Meteo_Exterior_Viento                           0.227334       -0.566022
# 15:Meteo_Exterior_Sol_Oest                        -0.430849        0.064335
# 16:Meteo_Exterior_Sol_Est                         -0.253164        0.353174
# 17:Meteo_Exterior_Sol_Sud                         -0.400390        0.275979
# 18:Meteo_Exterior_Piranometro                     -0.415065        0.216753
# 19:Exterior_Entalpic_1                                  NaN             NaN
# 20:Exterior_Entalpic_2                                  NaN             NaN
# 21:Exterior_Entalpic_turbo                              NaN             NaN
# 22:Temperature_Exterior_Sensor                    -0.635860        0.192651
# 23:Humedad_Exterior_Sensor                         1.000000       -0.721302
# 24:Day_Of_Week                                    -0.721302        1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# Analyzing the data, we decide to futher investigate the correlation among indoor temperature, outdoor temperature, solar irradiance (measured by a piranometer) and inside lighting

# %%
# building a normalized dataframe and adding subplots in order to show the correlation graphically 
Normalized_DF=DF_cleaned.copy()

# removing not correlated columns
Normalized_DF.drop(Normalized_DF.columns[[0,1,10,11,12,13,14,15,17,18,19,22,23]],axis=1,inplace=True) 

# normalizing
Max = Normalized_DF.max() 
Min = Normalized_DF.min()
Normalized_DF= (Normalized_DF-Min)/(Max-Min)

fig = plt.figure()
ax1= fig.add_subplot(3,1,1) 
ax2= fig.add_subplot(3,1,2)
ax3= fig.add_subplot(3,1,3)

Normalized_DF["18:Meteo_Exterior_Piranometro"].plot(ax=ax1,color= "g", legend= True)
Normalized_DF["5:Weather_Temperature"].plot(ax=ax1,color= "y", legend= True)
Normalized_DF["22:Temperature_Exterior_Sensor"].plot(ax=ax2,color= "r", legend= True)
Normalized_DF["4:Temperature_Habitacion_Sensor"].plot(ax=ax2,color= "k", legend= True)
Normalized_DF["10:Lighting_Comedor_Sensor"].plot(ax=ax3,color= "b", legend= True)
Normalized_DF["11:Lighting_Habitacion_Sensor"].plot(ax=ax3,color= "c", legend= True)
plt.show()

# %% [markdown]
# From this graph we can observe that there is a delay between solar irradiance and both temperatures

# %%
# defining a function which calculates the lag, generate columns with a delay of time and save them in a new dataframe
DF_FinalDataSet= DF_cleaned.copy()

def lag_column(df,column_name,lag_period=1):
    for i in range(1,lag_period+1,1):
        new_column_name= column_name+"-"+str(i)+"hr"
        df[new_column_name]= df[column_name].shift(i)
  
    return df

DF_FinalDataSet= lag_column(DF_FinalDataSet,"4:Temperature_Habitacion_Sensor",24)
DF_FinalDataSet.dropna(inplace=True)

# %% [markdown]
# We apply the shift to the indoor temperature, because it is the parameter which presents a delay w.r.t. the solar irradiance

# %%
# removing the columns which we do not include in the model 
DF_FinalDataSet.drop(DF_FinalDataSet.columns[[0,1,6,8,9,10,11,12,13,14,15,17,18,19,23]],axis=1,inplace=True);
DF_FinalDataSet.dropna(inplace=True)    
DF_FinalDataSet.corr()

# splitting the data in two different dataframe
# DF_target contains the parameter that we want to predict, DF_features is the original dataframe without the target column 
DF_target = DF_FinalDataSet["4:Temperature_Habitacion_Sensor"]
DF_features = DF_FinalDataSet.drop("4:Temperature_Habitacion_Sensor", axis = 1)

# now that we have input(features) and output(target) we can build the model
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(DF_features,DF_target,test_size=0.2,random_state=41234)

# %% [markdown]
# The test_size represents the percentage of data used for testing, in our case 20% for testing while 80% for checking

# %%
# testing the model
from sklearn import linear_model
linear_reg = linear_model.LinearRegression()

# %%
# defining the linear model with training data (20%)
linear_reg.fit(X_train,Y_train)

# testing the plot with the other checking data (80%)
predict_linearReg_split = linear_reg.predict(X_test)

#collecting them in a dataframe
Y_test.index
predict_DF_linearReg_split = pd.DataFrame(predict_linearReg_split,index = Y_test.index,columns = ["TempPredict_LinReg"])
predict_DF_linearReg_split = predict_DF_linearReg_split.join(Y_test)
predict_DF_linearReg_split_ChosenDates = predict_DF_linearReg_split["2012-03-20":"2012-03-23"]

predict_DF_linearReg_split_ChosenDates.plot()
plt.xlabel("time")
plt.ylabel("temperature")
plt.title("Linear Regression Prediction")
plt.show()

# %%
# finding the metrics related to linear regression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mean_absolute_error_linearReg_split = mean_absolute_error(Y_test,predict_linearReg_split)
mean_squared_error_linearReg_split = mean_squared_error(Y_test,predict_linearReg_split)
R2_score_linearReg_split = r2_score(Y_test,predict_linearReg_split)

print 'Coefficient of determination (R-squared) = '+str(R2_score_linearReg_split)
# Out:
# Coefficient of determination (R-squared) = 0.995017871285

# %%
# using another method called cross validation
from sklearn.model_selection import cross_val_predict
predict_linearReg_CV = cross_val_predict(linear_reg,DF_features,DF_target,cv=10)
predict_DF_linearReg_CV = pd.DataFrame(predict_linearReg_CV,index = DF_target.index,columns = ["TempPredict_CrossVal"])
predict_DF_linearReg_CV = predict_DF_linearReg_CV.join(DF_target)
predict_DF_linearReg_CV_ChosenDates = predict_DF_linearReg_CV["2012-03-20 12:00:00 ":"2012-03-23 12:00:00"]
predict_DF_linearReg_CV_ChosenDates.plot()
plt.xlabel("time")
plt.ylabel("temperature")
plt.title("Cross Validation Prediction")
plt.show(1)

# %%
# finding the metrics related to cross validation 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mean_absolute_error_linearReg_CV = mean_absolute_error(DF_target,predict_linearReg_CV)
mean_squared_error_linearReg_CV = mean_squared_error(DF_target,predict_linearReg_CV)
R2_score_linearReg_CV = r2_score(DF_target,predict_linearReg_CV)
print 'Coefficient of determination (R-squared) = '+str(R2_score_linearReg_CV)
# Out:
# Coefficient of determination (R-squared) = 0.997666834876

# %% [markdown]
# # Conclusion
# We can point out that both models turn to be a good approximation of the actual values behaviour. In particular, the cross validation is the model which reaches higher R-Squared showing to be the best fit.
